# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris_df = pd.read_csv('IRIS.csv')

# %%
iris_df
# Out:
#      Sepal length  Sepal width  Petal length  Petal width          Specie
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal length  150 non-null    float64
#  1   Sepal width   150 non-null    float64
#  2   Petal length  150 non-null    float64
#  3   Petal width   150 non-null    float64
#  4   Specie        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_df.describe()
# Out:
#        Sepal length  Sepal width  Petal length  Petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
LabelEncoder_y = LabelEncoder()
iris_df['Specie'] = LabelEncoder_y.fit_transform(iris_df['Specie'])

# %%
iris_df
# Out:
#      Sepal length  Sepal width  Petal length  Petal width  Specie
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       2
# 146           6.3          2.5           5.0          1.9       2
# 147           6.5          3.0           5.2          2.0       2
# 148           6.2          3.4           5.4          2.3       2
# 149           5.9          3.0           5.1          1.8       2
#
# [150 rows x 5 columns]

# %%
iris_seto = iris_df[iris_df['Specie'] == 0 ]
iris_vers = iris_df[iris_df['Specie'] == 1 ]
iris_virg = iris_df[iris_df['Specie'] == 2 ]

# %%
print("Percentage of iris_setosa in dataset =", (len(iris_seto) / len(iris_df))*100, "%") 
print("Percentage of iris_versicolor in dataset =", (len(iris_vers) / len(iris_df))*100, "%") 
print("Percentage of iris_virginica in dataset =", (len(iris_virg) / len(iris_df))*100, "%")
# Out:
# Percentage of iris_setosa in dataset = 33.33333333333333 %
# Percentage of iris_versicolor in dataset = 33.33333333333333 %
# Percentage of iris_virginica in dataset = 33.33333333333333 %

# %%
plt.figure()
sns.heatmap(iris_df.corr(), annot = True)
# Out:
# <AxesSubplot: >

# %%
sns.pairplot(iris_df, hue='Specie')
plt.show()

# %%
sns.violinplot(data=iris_df, x="Specie", y="Sepal length", hue="Specie", inner="stick")
plt.show()
sns.violinplot(data=iris_df, x="Specie", y="Petal length", hue="Specie", inner="stick")
plt.show()
sns.violinplot(data=iris_df, x="Specie", y="Sepal width", hue="Specie", inner="stick")
plt.show()
sns.violinplot(data=iris_df, x="Specie", y="Petal width", hue="Specie", inner="stick")
plt.show()

# %%
sns.countplot(x = iris_df['Specie'], label = "Count")
# Out:
# <AxesSubplot: xlabel='Specie', ylabel='count'>

# %%
X = iris_df.drop(["Specie"], axis = 1)
y = iris_df["Specie"]

# %%
X
# Out:
#      Sepal length  Sepal width  Petal length  Petal width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Specie, Length: 150, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape
# Out:
# (120, 4)

# %%
y_train.shape
# Out:
# (120,)

# %%
X_test.shape
# Out:
# (30, 4)

# %%
y_test.shape
# Out:
# (30,)

# %%
#scaling features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(X_train, y_train)
# Out:
# SVC()

# %%
from sklearn.metrics import classification_report, confusion_matrix
y_predict_test = model.predict(X_test)
cm = confusion_matrix(y_test, y_predict_test)
sns.heatmap(cm, annot = True)
# Out:
# <AxesSubplot: >

# %%
print(classification_report(y_test, y_predict_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.90      0.90      0.90        10
#            2       0.90      0.90      0.90        10
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

print("\nEnter Iris measurements for classification:")
sepal_length = float(input("Sepal Length (cm): "))
sepal_width = float(input("Sepal Width (cm): "))
petal_length = float(input("Petal Length (cm): "))
petal_width = float(input("Petal Width (cm): "))

user_data = np.array([])
user_data = [[sepal_length, sepal_width, petal_length, petal_width]]
user_prediction = model.predict(user_data)

if user_prediction == 0:
    print("Prediction of Species: Iris setosa")
elif user_prediction == 1:
    print("Prediction of Species: Iris versicolor")
elif user_prediction == 2:
    print("Prediction of Species: Iris virginica")
else:
    print("Error in model")
# Out:
# Enter Iris measurements for classification:
# Sepal Length (cm):  2
# Sepal Width (cm):  2
# Petal Length (cm):  2
# Petal Width (cm):  2
# Prediction of Species: Iris virginica
